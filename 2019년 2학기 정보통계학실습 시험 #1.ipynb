# %% [markdown]
# # 2019년 1학기 통계 프로그래밍 시험 # 1
# ---
#
# ** 유의사항 **
#
# * 시험을 시작하기 전에 쥬피터 노트북 파일 이름을 **학과_학번_이름.ipynb**로 변경한다.
# * 각 문제 아래에 코드 셀을 추가하여 프로그램을 작성한다.
# * 시험이 종료하면 쥬피터 노트북을 메일에 첨부하여 joongyang.park@gmail.com로 보낸다.
# * 시험 감독관이 메일을 확인한 후에 퇴실해야 한다.
# * 시험의 만점은 30점이며 각 문제의 배점은 3점이다.

# %% [markdown]
# ### 1. 학생 본인의 이름과 학번, 그리고 나이를 변수에 저장하고, 각 변수에 저장된 값과 자료형을 화면에 출력하시오. **변수 이름**은 영문으로 하고, 변수에 저장할 값의 적절한 자료형을 선택해야 한다.

# %% [markdown]
# ### 2. 인터넷에서 '파이썬 위키피디어'를 검색한 결과의 첫 사이트를 클릭한 한 다음 이 사이트의 인터넷 주소(url)과 이 사이트에서 파이썬을 개발한 사람의 이름을 찾아서 변수에 저장하고 출력하시오.

# %% [markdown]
# ### 3. 아래에 텍스트 셀을 추가하고 앞 문제에서 찾은 사이트에 있는 파이썬 개발자의 사진을 텍스트 셀에 나타내시오.

# %% [markdown]
# ### 4. 아래 표에 있는 여러 자료를 변수에 저장하고 출력하는 프로그램을 작성하시오. 변수 이름은 영문으로 해야 한다.
#
# 이름 | 성별 | 생년월일 | 키 | 몸무게
# ---|---|---|---|---
# Park | male | 001003 | 185.2 | 80.2

# %% [markdown]
# ### 5. 3차원 공간 상의 두 점 $A = (x_{1}, y_{1}, z_1)$와 $B = (x_{2}, y_{2}, z_2)$ 사이의 거리는 다음과 같이 계산한다.
#
# $${\displaystyle d={\sqrt {(x_{2} - x_{1})^{2} + (y_{2} - y_{1})^{2} + (z_1 - z_2)^2} } }$$
#
# 두 점 **$A = (1, 2, 3), B = (5, 3, 1)$** 사이의 거리를 구하시오.

# %% [markdown]
# ### 6. 밑변이 3이고 높이가 5인 직각 삼각형의 빗변의 길이를 구하시오.

# %% [markdown]
# ### 7. 앞 문제에서 다룬 직각 삼각형의 두 각을 구하시오. 직각 삼각형의 각 변의 길이를 알고 있으므로 각도의 싸인과 코싸인을 구할 수 있고, 싸인과 코싸인의 역싸인과 역코싸인을 구하면 각도를 구할 수 있다.

# %% [markdown]
# ### 8. 자전거를 타고 초당 6m로 속도로 달린다고 하자. 총 25.2km를 달렸을때 걸린 시간을 시, 분, 초를 계산하시오.

# %% [markdown]
# ### 9.  해외여행에 필요한 돈을 달러로 환전하기 위해 은행을 찾았다. 30만원을 환전하면 미화(미국 달러)로 얼마인지를 계산하시오. 프로그램에 필요한 환율은 인테넷에서 검색하시오.

# %% [markdown]
# ### 10. $\bar{x}$ = 10, $n$ = 30, $\sigma$ = 1.2일 때 다음 두 식의 값을 계산하시오.
#
# $$\bar{x}-1.96{\sigma  \over {\sqrt {n}}}, \quad \quad {\bar {x}}+1.96{\sigma  \over {\sqrt {n}}}$$
