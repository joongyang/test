# %% [markdown]
# # 2019년 1학기 통계 프로그래밍 시험 # 3
# ---
#
# ** 유의사항 **
#
# * 시험을 시작하기 전에 쥬피터 노트북 파일 이름을 **학과_학번_이름_3차시험.ipynb**로 변경한다.
# * 각 문제 아래에 코드 셀을 추가하여 프로그램을 작성한다.
# * 시험이 종료하면 쥬피터 노트북을 메일에 첨부하여 joongyang.park@gmail.com로 보낸다.
# * 시험 감독관이 메일을 확인한 후에 퇴실해야 한다.
# * 시험의 만점은 30점이며 각 문제의 배점은 3점이다.

# %% [markdown]
# ### 1. 1과 1000 사이에 있는 모든 7의 배수의 합을 구하는 프로그램을 반복문(for)을 이용하여 작성하시오

# %% [markdown]
# ### 2. 아래 프로그램을 실행하고 그 결과로 생성되는 numbers 리스트에서 홀수를 추출하여 odds 리스트에, 짝수를 추출하여 evens 리스트에 저장하고, 홀수와 짝수의 개수를 출력하는 프로그램을 작성하시오.

# %%
import random
random.seed(12345)
numbers = []
for i in range(100):
    numbers.append(random.randint(0, 1000))

print(numbers)
# Out:
# [426, 750, 10, 839, 845, 822, 305, 875, 377, 954, 198, 276, 579, 446, 165, 382, 127, 895, 443, 267, 575, 642, 178, 626, 566, 191, 363, 755, 981, 750, 93, 543, 753, 422, 599, 516, 170, 151, 210, 736, 79, 194, 857, 349, 329, 24, 469, 347, 27, 990, 522, 707, 762, 425, 3, 6, 962, 679, 891, 167, 789, 594, 183, 293, 101, 668, 424, 108, 906, 697, 591, 186, 754, 384, 238, 983, 536, 610, 726, 935, 844, 337, 826, 41, 237, 122, 894, 511, 221, 754, 821, 774, 568, 685, 190, 263, 602, 444, 530, 938]

# %% [markdown]
# ### 3. 아래 프로그램을 실행하고 그 결과로 생성되는 리스트 labels에는 임의 현상에서 나타날 수 있는 결과가 저장되어 있고, 리스트 prob에는 각 결과가 나타날 수 있는 확률이 저장되어 있다. 나타날 확률이 가장 큰 임의 현상의 결과를 구하는 프로그램을 작성하시오.

# %%
labels = ['개','고양이','토끼']
prob = [0.2, 0.3, 0.5]

# %% [markdown]
# ### 4. 다음 프로그램을 실행하면 후보자 이름이 저장된 candidate 리스트와 각 후보자가 얻은 투표수가 저장된 votes 리스트가 생성된다. 이 두 리스트를 이용하여 각 후보자의 득표율이 저장된 리스트를 만드는 프로그램을 작성하시오.

# %%
candidates =['박아무개','홍두께','권도사']
votes = [12345, 23456, 34567]

# %% [markdown]
# ### 5. 다음은 $A = (x_{1}, y_{1}, z_{1}), B = (x_2, y_2, z_2)$는 두 점의 사이의 거리를 구하는 식이다.
#
# $$
# \bar{AB} = \sqrt{ (x_{1} - x_{2})^{2} + (y_{1} - y_{2})^{2} + (z_{1}-z_{2})^{2}}
# $$
#
# 아래 프로그램의 리스트 A, B는 두 점의 좌표를 저장하고 있다.
# 이 두 점의 사이의 거리를 계산하고 출력하는 프로그램을 작성하시오.

# %%
import math

A = [1,2,3]
B = [4,5,6]

# %% [markdown]
# ### 6. 2019년 최저 시급은 시간당 8350원이며, 휴일(주말 포함) 근무 시에는 시급에 50%를 가산하여 지급한다. 일 주일 동안 아래 표와 같이 일하였다. 일한 시간을 실수로 저장한 리스트 hours를 만들고(예를 들어 7시간 30분은 7.5임), 주급이 얼마인지 계산하는 프로그램을 작성하시오.
#
# 요일 | 시간 |
# ---|---
# 월 | 8시간
# 화 | 7시간 30분
# 수 | 7시간
# 목 | 5시간 30분
# 금 | 3시간
# 토 | 4시간
# 일 | 6시간

# %% [markdown]
# ### 7. 다음 프로그램의 students와 scores는 학생의 이름과 성적이 저장된 리스트이다. 키보드에서 본인의 이름과 예상 성적을 입력 받아 이 두 리스트에 추가하는 프로그램을 작성하시오.

# %%
students = ['김모군','이모양','현모씨','조모모']
scores = [3.5, 4.1, 2.5, 4.0]

# %% [markdown]
# ### 8. 7번 문제와 연결하여 키보드로 학생의 이름을 입력 받아 해당 학생의 성적을 출력하는 프로그램을 작성하시오.

# %% [markdown]
# ### 9. 아래 프로그램은  (0, 10) 구간을 1000 등분한 점에서 함수 $\ln \left( x + \sqrt{x^2 + 1} \right)$의 값을 계산하는 프로그램 이다. 밑줄친 부분을 채워 프로그램을 완성하시오.

# %%
import math

fx = []

for i in range(1001):
    x = _______
    fx.append(_______)
print(fx[:10])

# %% [markdown]
# ### 10. 아래 주어진 리스트 score의 자료를 이용하여 함수를 이용하지 않고 평균과 표준편차 $s = \sqrt{\sum_{i=1}^n \left( x_i - \bar{x} \right)^2 / \left( n - 1 \right)}$를 계산하는 프로그램을 작성하고 결과를 출력하시오. 평균과 표준편차를 statistics 모듈에 정의된 함수를 이용하여 계산한 결과와 같은지도 알아보시오.

# %%
score = [3.5, 3.7, 2.5, 4.0, 4.1, 3.2, 3.6, 4.3, 4.5, 2.1, 1.5, 2.7, 2.9, 3.9, 1.9, 3.2]
